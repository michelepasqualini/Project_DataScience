# %% [markdown]
# # Powerlifting

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as pt
import plotly.express as px
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim

# %%
powerlifting = pd.read_csv("Powerlifting/openpowerlifting.csv")
powerlifting.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# 0            60       NaN        47.63       NaN        20.41          NaN
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# ...

# %%
meets = pd.read_csv("Powerlifting/meets.csv")
meets.head()
# Out:
#    MeetID        MeetPath Federation        Date MeetCountry MeetState  \
# 0       0  365strong/1601  365Strong  2016-10-29         USA        NC
# 1       1  365strong/1602  365Strong  2016-11-19         USA        MO
# 2       2  365strong/1603  365Strong  2016-07-09         USA        NC
# 3       3  365strong/1604  365Strong  2016-06-11         USA        SC
# 4       4  365strong/1605  365Strong  2016-04-10         USA        SC
#
#     MeetTown                                           MeetName
# 0  Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 1      Ozark                  Thanksgiving Powerlifting Classic
# 2  Charlotte                             Charlotte Europa Games
# 3  Rock Hill                   Carolina Cup Push Pull Challenge
# 4  Rock Hill                              Eastern USA Challenge

# %%
openpowerlifting = pd.merge(left=powerlifting, right=meets, how='inner', on='MeetID')
openpowerlifting.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  ...  TotalKg  Place   Wilks  \
# 0            60       NaN        47.63  ...   138.35      1  155.05
# 1            60       NaN       142.88  ...   401.42      1  456.38
# 2            60       NaN       142.88  ...   401.42      1  456.38
# 3            60       NaN          NaN  ...    95.25      1  108.29
# 4          67.5       NaN          NaN  ...   122.47      1  130.47
#
#          MeetPath  Federation        Date  MeetCountry MeetState   MeetTown  \
# ...

# %%
count_state=openpowerlifting.groupby(['MeetState']).size()
#print(count_state)
#the full dataframe
df_order = pd.DataFrame(count_state.sort_values(ascending = False))

#the top 5
df2 = df_plot[:10].copy()
print(df_order[:10])
print(df_order[:-10])
#df2.loc['others'] = count_state[:-10].sum()


#df2 = pd.concat([df2, new_row])
#print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Utente\Desktop\Progetto_DataScience\Project_DataScience\analisi_plift.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Utente/Desktop/Progetto_DataScience/Project_DataScience/analisi_plift.ipynb#ch0000005?line=3'>4</a> df_order = pd.DataFrame(count_state.sort_values(ascending = False))
#       <a href='vscode-notebook-cell:/c%3A/Users/Utente/Desktop/Progetto_DataScience/Project_DataScience/analisi_plift.ipynb#ch0000005?line=5'>6</a> #the top 5
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Utente/Desktop/Progetto_DataScience/Project_DataScience/analisi_plift.ipynb#ch0000005?line=6'>7</a> df2 = df_plot[:10].copy()
#       <a href='vscode-notebook-cell:/c%3A/Users/Utente/Desktop/Progetto_DataScience/Project_DataScience/analisi_plift.ipynb#ch0000005?line=7'>8</a> print(df_order[:10])
# ...

# %%
'''


#combining top 5 with others
df2 = pd.concat([df2, new_row])
# Creating plot
fig = plt.figure(figsize =(10, 10))
plt.pie(df2, labels=df2.index, autopct='%1.0f%%', pctdistance=1.1, labeldistance=1.2)
 
# show plot
plt.show()
'''

# %%
import plotly.figure_factory as ff

# %%
count_state=openpowerlifting.groupby(['MeetTown']).count()
fig = px.scatter_mapbox(count_state, hover_name=count_state.index, hover_data="MeetID" ,color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3359'>3360</a> try:
# -> <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3360'>3361</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3361'>3362</a> except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
count_state=openpowerlifting.groupby(['MeetTown']).count()
print(count_state)

fig = px.choropleth_mapbox(count_state,
                    #geojson=count,
                    locations=count_state.index,
                    color=count_state['MeetID'],
                    hover_name=count_state.index,
                    hover_data=count_state['MeetID'],
                    color_continuous_scale="Viridis",
                    range_color=(0, 12),
                    mapbox_style="carto-positron",
                    zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                    labels={'MeetTown':'MeetID'},
                    opacity=0.5)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
#                      MeetID  Name   Sex  Equipment  Age  Division  \
# MeetTown
# Aas                       5     5     5          5    0         5
# Abbotsford              751   751   751        751    0       751
# Aberdeen                231   231   231        231  231       231
# Abernathy               173   173   173        173    0       173
# Abilene                1351  1351  1351       1351    0      1351
# ...                     ...   ...   ...        ...  ...       ...
# Ø. Årdal                  6     6     6          6    0         6
# Øksfjord Atletklubb       7     7     7          7    0         7
# Ørebro                   10    10    10         10    0        10
# Ørskog                   13    13    13         13    0        13
# Østfold Næringspark      58    58    58         58    0        58
#
#                      BodyweightKg  WeightClassKg  Squat4Kg  BestSquatKg  ...  \
# MeetTown                                                                 ...
# ...
